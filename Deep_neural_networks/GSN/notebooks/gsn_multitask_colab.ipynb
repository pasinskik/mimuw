# %% [markdown]
# <a href="https://colab.research.google.com/github/pasinskik/mimuw/blob/main/Deep_neural_networks/GSN/notebooks/gsn_multitask_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repo into the Colab runtime
# !git clone https://github.com/pasinskik/mimuw.git

# Go inside the repo
# %cd mimuw/Deep_neural_networks/GSN
# Out:
# Cloning into 'mimuw'...
# remote: Enumerating objects: 10383, done.
# remote: Counting objects: 100% (10383/10383), done.
# remote: Compressing objects: 100% (10319/10319), done.
# remote: Total 10383 (delta 77), reused 10349 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (10383/10383), 13.75 MiB | 7.93 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# Updating files: 100% (10156/10156), done.
# /content/mimuw/Deep_neural_networks/GSN/mimuw/Deep_neural_networks/GSN

# %%
# !pip install -r requirements.txt
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
#   Using cached torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ...
#   Using cached torchaudio-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# ...
#   Using cached torchvision-0.23.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# ...
# Using cached torch-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl (887.9 MB)
# Using cached torchaudio-2.8.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.0 MB)
# Using cached torchvision-0.23.0-cp312-cp312-manylinux_2_28_x86_64.whl (8.6 MB)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu126
#     Uninstalling torchvision-0.24.0+cu126:
#       Successfully uninstalled torchvision-0.24.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.9.0+cu126
# ...

# %%
# Run all required experiments
# !python train_multitask.py \
    --run_all \
    --epochs 100 \
    --patience 10 \
    --device cuda
# Out:
# ========== Running experiment: cls ==========
# Epoch 01 | train_loss=4.7201 | val_loss=4.6719 | val_acc=0.0110 | val_f1=0.0002 | val_pair_acc=0.0680 | val_rmse=3.1679 | val_mae=1.8109
# Epoch 02 | train_loss=4.6718 | val_loss=4.6545 | val_acc=0.0120 | val_f1=0.0007 | val_pair_acc=0.0700 | val_rmse=3.1143 | val_mae=1.7135
# Epoch 03 | train_loss=4.4604 | val_loss=4.1209 | val_acc=0.0310 | val_f1=0.0102 | val_pair_acc=0.1530 | val_rmse=2.9018 | val_mae=1.8168
# Epoch 04 | train_loss=3.9606 | val_loss=3.8788 | val_acc=0.0390 | val_f1=0.0119 | val_pair_acc=0.1640 | val_rmse=2.8478 | val_mae=1.9586
# Epoch 05 | train_loss=3.7826 | val_loss=3.6809 | val_acc=0.0710 | val_f1=0.0338 | val_pair_acc=0.2660 | val_rmse=2.7925 | val_mae=1.9629
# Epoch 06 | train_loss=3.4521 | val_loss=3.3196 | val_acc=0.0940 | val_f1=0.0537 | val_pair_acc=0.3260 | val_rmse=2.8178 | val_mae=1.9975
# ...
